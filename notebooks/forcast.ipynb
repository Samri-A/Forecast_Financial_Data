# %%
import sys
sys.path.append("../scripts")
from forcast import forcast_port

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
for_predict = forcast_port('../model/lstm_model.pkl')

# %% [markdown]
# # TSLA

# %%
TSLA_6month = for_predict.predict("../data/TSLA_10years_data.csv" , 180)

# %%
TSLA_6month.shape
# Out:
# (180, 1)

# %%
for_predict.plot_forcast( '2025-08-08' ,  TSLA_6month ,180 ,"../data/TSLA_10years_data.csv" )

# %% [markdown]
# # SPY

# %%
SPY_6month = for_predict.predict("../data/SPY_10years_data.csv" , 180)

# %%
for_predict.plot_forcast( '2025-08-08'  , SPY_6month , 180 , "../data/SPY_10years_data.csv")

# %% [markdown]
# # BND

# %%
BND_6months = for_predict.predict("../data/BND_10years_data.csv" , 180)

# %%
for_predict.plot_forcast( '2025-08-08'  , BND_6months , 180 , "../data/BND_10years_data.csv")
